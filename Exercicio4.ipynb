# %%
import pandas as pd
#Definindo as variaveis que são utilizadas para abrigar os data frame
vendas_df = pd.read_csv("Contoso - Vendas - 2017.csv", sep = ";")
produtos_df = pd.read_csv("Contoso - Cadastro Produtos.csv", sep = ";")
lojas_df = pd.read_csv("Contoso - Lojas.csv", sep = ";", encoding = "ISO-8859-1")
clientes_df = pd.read_csv("Contoso - Clientes.csv", sep= ";", encoding = "ISO-8859-1")

#Seprando colunas especificas de maneira com que, o dataframe irá abrigar somente as colunas especificos 
clientes_df = clientes_df[["ÿID Cliente","E-mail"]]
produtos_df = produtos_df[["Nome da Marca","ID Produto"]]
lojas_df = lojas_df[["ÿID Loja", "Nome da Loja"]]

#Renomeando colunas com a função .rename()
clientes_df = clientes_df.rename(columns = {"ÿID Cliente": "ID Cliente"})
lojas_df = lojas_df.rename(columns = {"ÿID Loja": "ID Loja"})

#juntando as colunas separadas com o dataframe, vendas_df, utilizando a função .merge()
vendas_df = vendas_df.merge(produtos_df, on="ID Produto")
vendas_df = vendas_df.merge(lojas_df, on="ID Loja")
vendas_df = vendas_df.merge(clientes_df, on= "ID Cliente")

#Renomando outra coluna dentro do dataframe finalizado.
vendas_df = vendas_df.rename(columns = {"E-mail": "E-mail Clientes"})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    23/11/2017    23/11/2017         0      110
# 980638           920243    09/12/2017    10/12/2017         1      261
# 980639           467482    21/06/2017    25/06/2017         4      115
# 980640           853643    13/11/2017    20/11/2017         7      115
# 980641           903958    02/12/2017    02/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
#modificando o tipo de dados presente na coluna "Data do Envio" e "Data da Venda", com a função pd.to_datetime().
vendas_df["Data do Envio"] = pd.to_datetime(vendas_df["Data do Envio"], format = "%d/%m/%Y")
vendas_df["Data da Venda"] = pd.to_datetime(vendas_df["Data da Venda"], format ="%d/%m/%Y" )
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    2017-01-01    2017-01-02         1       86
# 1                880458    2017-11-23    2017-11-23         0      306
# 2                191019    2017-03-20    2017-03-21         1      172
# 3                 18610    2017-01-08    2017-01-10         2      200
# 4                287704    2017-04-23    2017-04-26         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    2017-11-23    2017-11-23         0      110
# 980638           920243    2017-12-09    2017-12-10         1      261
# 980639           467482    2017-06-21    2017-06-25         4      115
# 980640           853643    2017-11-13    2017-11-20         7      115
# 980641           903958    2017-12-02    2017-12-02         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
#criando novas colunas de ano, mes e dia, baseado na coluna "Data da Venda" depois de ter sido modificada
vendas_df["Dia da Venda"] = vendas_df["Data da Venda"].dt.day
vendas_df["Mes da Venda"] = vendas_df["Data da Venda"].dt.month
vendas_df["Ano da venda"] = vendas_df["Data da Venda"].dt.year
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    2017-01-01    2017-01-02         1       86
# 1                880458    2017-11-23    2017-11-23         0      306
# 2                191019    2017-03-20    2017-03-21         1      172
# 3                 18610    2017-01-08    2017-01-10         2      200
# 4                287704    2017-04-23    2017-04-26         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           878244    2017-11-23    2017-11-23         0      110
# 980638           920243    2017-12-09    2017-12-10         1      261
# 980639           467482    2017-06-21    2017-06-25         4      115
# 980640           853643    2017-11-13    2017-11-20         7      115
# 980641           903958    2017-12-02    2017-12-02         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
#Aqui foi estabelecido um filtro onde é extraído as informações baseada em certas condições de "ID da lajo", "Mes da Venda" e "Dia da Venda"
LCEO = vendas_df[(vendas_df["ID Loja"] == 306) & (vendas_df["Mes da Venda"]>= 1) & (vendas_df["Mes da Venda"] <= 7) & (vendas_df["Dia da Venda"] <= 15)]
LCEO = LCEO.sort_values("Mes da Venda", ascending = True)
display(LCEO)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 229               24931    2017-01-11    2017-01-17         6      306
# 227336            14086    2017-01-06    2017-01-06         0      306
# 725841            20105    2017-01-09    2017-01-09         0      306
# 227864            17706    2017-01-08    2017-01-10         2      306
# 227865             5969    2017-01-03    2017-01-03         0      306
# ...                 ...           ...           ...       ...      ...
# 716675           520060    2017-07-10    2017-07-12         2      306
# 717383           521404    2017-07-11    2017-07-17         6      306
# 717409           528911    2017-07-14    2017-07-19         5      306
# 715824           502130    2017-07-03    2017-07-03         0      306
# 882103           517736    2017-07-09    2017-07-09         0      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
novo_df = pd.read_csv(r"Contoso - Cadastro Produtos.csv",sep =";")
#importando o arquivo csv e criando um dataframe 

novo_df = novo_df.set_index("ID Produto")
display(novo_df)
#com a "função set_index()", o indice que seria o numero padrão das colunas, agora passará a ser por definição da função a coluna "nome da marca"
novo_df.loc[879,"Nome da Marca"]
# a função ".loc()", é utilizada para travar e retornar a informação de uma linha baseada no indice especificado.
#É possivel retornar somente o valor de uma coluna, passando o segundo parametro especificando a coluna que quer retornar a informação
# Out:
#                Nome da Marca       Tipo Custo Unitario Preco Unitario  \
# ID Produto
# 873                  Contoso  Econômico          10,69          20,96
# 879                  Contoso  Econômico           6,63             13
# 880                  Contoso  Econômico           6,63             13
# 881                  Contoso  Econômico           6,63             13
# 882                  Contoso  Econômico           6,63             13
# ...                      ...        ...            ...            ...
# 1602        Southridge Video    Regular          82,77         179,99
# 1606        Southridge Video    Regular          73,57         159,99
# 1607        Southridge Video    Regular          82,77         179,99
# 1611        Southridge Video    Regular          73,57         159,99
# 1612        Southridge Video    Regular          82,77         179,99
#
#                             Categoria
# ID Produto
# 873         Acessório para Computador
# ...

# %%
#Aqui, está sendo modificado, o valor na coluna "Preco Unitario" utilizando a função ".loc()" e especificando o valor a ser adicionado aquele indice
novo_df.loc[1602, "Preco Unitario"] = 350 
display(novo_df.loc[1602])
# Out:
# Nome da Marca     Southridge Video
# Tipo                       Regular
# Custo Unitario               82,77
# Preco Unitario                 350
# Categoria                Filme DVD
# Name: 1602, dtype: object
